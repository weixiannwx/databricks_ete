# %%
# %fs
ls dbfs:/

# %%
dbutils.fs.ls("dbfs:/")

# %%
# %fs mounts

# %%
# %fs
ls file:/

# %%
dbutils.fs.ls("file:/")

# %%
# %sh
tail /databricks-datasets/songs/data-001/part-00091

# %%
# %env?

# %%
# %pip??
