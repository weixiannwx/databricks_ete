# %%
source_file_names = [
    {
        'file_name' : 'orders'
    },
    {
        'file_name' : 'customers'
    },
    {
        'file_name' : 'products'
    }
]

# %%
dbutils.jobs.taskValues.set('source_file_names', source_file_names)
