# %%
df = (
    spark
    .read
    .table('databricks_cata.bronze.regions')
)
df.display()

# %%
(
    df
    .write
    .format('delta')
    .mode('overwrite')
    .save('abfss://silver@databricksstorageete.dfs.core.windows.net/regions')
)

# %%
# %sql
CREATE TABLE IF NOT EXISTS databricks_cata.silver.regions
USING DELTA
LOCATION 'abfss://silver@databricksstorageete.dfs.core.windows.net/regions';

# %%
# %sql
SELECT * FROM databricks_cata.silver.regions;

# %%
# %sql
DROP TABLE IF EXISTS databricks_cata.silver.region;
